# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# importing libraries

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.preprocessing import StandardScaler

# %%
# !unzip /content/creditcard.csv(1).zip
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `unzip /content/creditcard.csv(1).zip'

# %%
df=pd.read_csv('/content/creditcard.csv(1).zip')

# %%
# showing first five rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# showing info about all columns(datatype,count)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# showing statistical details
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# identifying dimensions of dataframe
np.shape(df)
# Out:
# (284807, 31)

# %%
# identifieng no columns
print("number of columns",df.shape[1])
# Out:
# number of columns 31

# %%
# identifieng no of rows
print("number of rows",df.shape[0])
# Out:
# number of rows 284807

# %%
# identifying number of duplicate values
print(df.duplicated().sum())
# Out:
# 1081

# %%
# removing duplicate values
df=df.drop_duplicates()

# %%
# identifieng no of duplicates values
print(df.duplicated().sum())
# Out:
# 0

# %%
df['Amount']
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 283726, dtype: float64

# %%
# storing standard scaller into a variable
sc=StandardScaler()

# %%
# to convert the series"Amount" to dataframe
df["Amount"]=sc.fit_transform(pd.DataFrame(df["Amount"]))

# %%
(df["Amount"])
# Out:
# 0         0.244200
# 1        -0.342584
# 2         1.158900
# 3         0.139886
# 4        -0.073813
#             ...
# 284802   -0.350252
# 284803   -0.254325
# 284804   -0.082239
# 284805   -0.313391
# 284806    0.513290
# Name: Amount, Length: 283726, dtype: float64

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df=df.drop(["Time"],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
plt.pie(df["Class"].value_counts(),labels=["normal","fraud"])
plt.show()

# %%
plt.scatter(df['V1'],df['V2'])
plt.show()

# %%
normal=df[df[('Class')]==0]

# %%
normal.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
fraud=df[df[('Class')]==1]

# %%
fraud.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 541   1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 623  -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 4920 -0.399147 -0.238253 -1.525412  ... -0.294166 -0.932391  0.172726
# 6108 -0.248778 -0.247768 -4.801637  ...  0.573574  0.176968 -0.436207
# 6329 -0.496358 -1.282858 -2.447469  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
normal.shape
# Out:
# (283253, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
newdf=pd.concat([normal_sample,fraud],ignore_index=True)

# %%
newdf.shape
# Out:
# (946, 30)

# %%
x=newdf.drop(columns='Class',axis=1)

# %%
x.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.616679  0.899691 -0.809588 -1.096636  2.333581  3.210555  0.158905
# 1 -1.156574  0.996434  0.838178 -0.867773  0.642522 -0.488091  0.631533
# 2 -1.348442 -0.458954  1.615984 -1.909024  0.419160 -0.367518  0.418770
# 3  2.054021  0.116949 -1.801197  0.229673  0.637202 -0.382046  0.090220
# 4 -0.328086  0.498565 -1.969437 -0.245311  1.623402 -1.368118  1.326602
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  1.190846 -1.004087 -0.660754  ...  0.035779  0.030531 -0.266708 -0.120363
# 1  0.421273 -1.007006 -0.999796  ... -0.103477 -0.189674 -0.784539 -0.318408
# 2 -0.270195 -1.416993  0.518176  ... -0.623060 -0.558148 -0.827915  0.248554
# 3 -0.082582  0.222151 -0.214962  ... -0.122497 -0.330199 -0.868861  0.288621
# 4 -0.273507 -0.414722 -0.768977  ... -0.283956  0.099849  0.670576  0.510664
#
#         V24       V25       V26       V27       V28    Amount
# ...

# %%
x=newdf.drop(['Class'],axis=1)

# %%
y=newdf['Class']
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 941    1
# 942    1
# 943    1
# 944    1
# 945    1
# Name: Class, Length: 946, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=101)

# %%
models=RandomForestClassifier(n_estimators=15,random_state=101)

# %%
models.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=15, random_state=101)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=models.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy:.2f}")
# Out:
# Accuracy:0.93
